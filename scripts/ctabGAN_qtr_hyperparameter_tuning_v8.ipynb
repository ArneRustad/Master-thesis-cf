# %%
import pathlib
import os
if not "changed_working_directory" in locals():
    changed_working_directory = True
    os.chdir(pathlib.Path().resolve().parent)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tabGAN import TabGAN
from src import constants as const
import helpers
from v2_hp_tuning import fetch_hp_info

imports_path = "src//imports.ipynb"
tabGAN_path = "tabGAN.py"
utils_path = "utils\\utils.ipynb"
import helpers.hp_tuning

# %run "$imports_path"

# %%
if const.dir.project() != os.getcwd():
    raise ValueError("Project directory not the same as in consts")

# %%
dataset_train_path = os.path.join(const.dir.data(), "df_adult_edited_train.csv")
dataset_test_path = os.path.join(const.dir.data(), "df_adult_edited_test.csv")

data_train = pd.read_csv(dataset_train_path)
data_test = pd.read_csv(dataset_test_path)
discrete_columns = data_train.columns[data_train.dtypes == "object"]

METHOD_NAME = "ctabGAN-qtr"

# %%
def plot_hp_tuning(hp_name, allow_not_complete_hp_vec=True, n_synthetic_datasets=None, **kwargs):
    hp_info = fetch_hp_info(method=METHOD_NAME, version=8)
    curr_image_dir = os.path.join(const.dir.images_hp_v8(), METHOD_NAME)
    curr_hp_info = hp_info[hp_name]
    if n_synthetic_datasets is None:
        n_synthetic_datasets = curr_hp_info["n_synthetic_datasets"]
    result = helpers.hp_tuning.evaluate_hyperparams_through_prediction(
        data_train=data_train, 
        data_test=data_test,
        dataset_dir=const.dir.hp_tuning_v8(),
        hyperparams_vec=curr_hp_info["vec"],
        hyperparams_name = hp_name,
        hyperparams_subname = curr_hp_info["hyperparams_subname"],
        subfolder=METHOD_NAME,
        n_synthetic_datasets = n_synthetic_datasets,
        save_dir = const.dir.images_hp_v8(),
        save_path = f"predictive_performance_against_{hp_name}.svg",
        incl_comparison_folder=True,
        allow_not_complete_hp_vec=allow_not_complete_hp_vec,
        **kwargs
    )
    return result

# %%
result_qtr_spread = plot_hp_tuning("qtr_spread")
# Out:
#   0%|          | 0/210 [00:00<?, ?it/s]

# %%
result_qtr_spread
# Out:
#     Qtr spread  Value Accuracy  Value AUC  Value F1  Value F1_0  Value F1_1  \
# 0         0.00        0.837231   0.892094  0.774933    0.893334    0.656532
# 1         0.05        0.836972   0.891962  0.774734    0.893133    0.656336
# 2         0.10        0.839117   0.893589  0.776963    0.894691    0.659235
# 3         0.15        0.838884   0.892765  0.775855    0.894702    0.657009
# 4         0.20        0.838207   0.892944  0.775402    0.894168    0.656636
# 5         0.25        0.836726   0.891701  0.773984    0.893061    0.654908
# 6         0.30        0.838247   0.892797  0.776030    0.894072    0.657988
# 7         0.35        0.837649   0.891769  0.775055    0.893708    0.656402
# 8         0.40        0.838333   0.893102  0.775711    0.894220    0.657203
# 9         0.45        0.837928   0.893181  0.775170    0.893952    0.656387
# 10        0.50        0.837776   0.893239  0.775460    0.893740    0.657179
# 11        0.55        0.837789   0.892507  0.775130    0.893827    0.656434
# 12        0.60        0.838167   0.892480  0.774737    0.894262    0.655212
# 13        0.65        0.838599   0.892947  0.776100    0.894388    0.657812
#
#     SD Accuracy    SD AUC     SD F1   SD F1_0   SD F1_1
# 0      0.002556  0.001848  0.003472  0.001903  0.005979
# 1      0.001896  0.002395  0.002738  0.001428  0.004899
# 2      0.001807  0.002225  0.002867  0.001420  0.005459
# 3      0.002919  0.002583  0.003682  0.002197  0.006206
# 4      0.002469  0.001743  0.003014  0.001742  0.004485
# 5      0.001802  0.001403  0.002327  0.001401  0.004096
# 6      0.001792  0.001061  0.001847  0.001378  0.002759
# 7      0.001975  0.000990  0.002677  0.001510  0.004719
# 8      0.001680  0.001340  0.003000  0.001107  0.005348
# 9      0.001785  0.001565  0.002684  0.001229  0.004544
# 10     0.002185  0.000942  0.002588  0.001728  0.004482
# 11     0.002012  0.001544  0.002458  0.001498  0.003981
# 12     0.001502  0.001797  0.003400  0.001002  0.006514
# 13     0.002095  0.001888  0.002360  0.001611  0.003819

# %%
result_best_activation_function = plot_hp_tuning("best_activation_function")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
result_best_activation_function
# Out:
#   Best activation function  Value Accuracy  Value AUC  Value F1  Value F1_0  \
# 0                     GELU        0.841434   0.895824  0.777382    0.896787
# 1                     Mish        0.841376   0.895261  0.776573    0.896896
#
#    Value F1_1  SD Accuracy    SD AUC     SD F1   SD F1_0   SD F1_1
# 0    0.657976     0.002229  0.001832  0.003738  0.001501  0.006559
# 1    0.656249     0.001982  0.001278  0.003020  0.001358  0.005128

# %%
result_noise_discrete_unif_max = plot_hp_tuning("noise_discrete_unif_max")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
result_adam_beta1 = plot_hp_tuning("adam_beta1")
# Out:
#   0%|          | 0/240 [00:00<?, ?it/s]

# %%
result_adam_beta1

# %%
result_oh_encoding = plot_hp_tuning("oh_encoding")
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
result_oh_encoding
# Out:
#     Temperature Activation function  Value Accuracy  Value AUC  Value F1  \
# 0           0.1              gumbel        0.840299   0.893830  0.775523
# 1           0.1             softmax        0.840950   0.895547  0.774979
# 2           0.2              gumbel        0.841753   0.895846  0.775467
# 3           0.2             softmax        0.842683   0.896495  0.778766
# 4           0.3              gumbel        0.841859   0.895841  0.776671
# 5           0.3             softmax        0.842802   0.897167  0.777499
# 6           0.4              gumbel        0.841859   0.895977  0.777393
# 7           0.4             softmax        0.842211   0.896386  0.777286
# 8           0.5              gumbel        0.841016   0.894842  0.775865
# 9           0.5             softmax        0.841029   0.895422  0.775186
# 10          0.6              gumbel        0.841906   0.895889  0.777882
# 11          0.6             softmax        0.841780   0.895178  0.775949
# 12          0.7              gumbel        0.841999   0.895922  0.776236
# 13          0.7             softmax        0.841746   0.896386  0.777345
# 14          0.8              gumbel        0.841275   0.895883  0.776106
# 15          0.8             softmax        0.841647   0.895761  0.775995
# 16          0.9              gumbel        0.841667   0.896014  0.776587
# 17          0.9             softmax        0.842390   0.895942  0.778717
# 18          1.0              gumbel        0.841321   0.895594  0.775751
# 19          1.0             softmax        0.841268   0.895241  0.775804
#
#     Value F1_0  Value F1_1  SD Accuracy    SD AUC     SD F1   SD F1_0  \
# 0     0.896099    0.654947     0.002081  0.001178  0.003552  0.001439
# 1     0.896814    0.653143     0.002166  0.001417  0.003217  0.001489
# 2     0.897460    0.653475     0.001648  0.001267  0.002476  0.001200
# 3     0.897670    0.659861     0.002587  0.001973  0.004175  0.001769
# 4     0.897326    0.656015     0.001807  0.001225  0.003459  0.001044
# 5     0.898032    0.656966     0.001529  0.001051  0.001825  0.001289
# 6     0.897182    0.657605     0.001578  0.001288  0.002085  0.001225
# 7     0.897529    0.657043     0.001237  0.000957  0.002453  0.000876
# 8     0.896704    0.655025     0.002383  0.001621  0.003624  0.001544
# 9     0.896842    0.653531     0.002094  0.002172  0.004325  0.001295
# 10    0.897128    0.658635     0.001405  0.001145  0.002346  0.001013
# 11    0.897390    0.654507     0.002366  0.001039  0.002640  0.001774
# 12    0.897540    0.654933     0.001258  0.000882  0.001880  0.000922
# 13    0.897088    0.657603     0.001378  0.001346  0.002573  0.000901
# 14    0.896893    0.655318     0.001415  0.001472  0.002945  0.000936
# 15    0.897260    0.654730     0.001373  0.001503  0.002604  0.000916
# 16    0.897162    0.656012     0.002244  0.001042  0.004273  0.001321
# 17    0.897410    0.660024     0.002338  0.001404  0.003184  0.001711
# 18    0.897008    0.654493     0.001772  0.001328  0.003020  0.001139
# 19    0.896949    0.654659     0.001818  0.000967  0.002383  0.001287
#
#      SD F1_1
# 0   0.006387
# 1   0.005410
# 2   0.004396
# 3   0.007281
# 4   0.006017
# 5   0.003561
# 6   0.003743
# 7   0.004649
# 8   0.005891
# 9   0.007890
# 10  0.004289
# 11  0.004136
# 12  0.003350
# 13  0.004644
# 14  0.005511
# 15  0.004763
# 16  0.007469
# 17  0.005415
# 18  0.005205
# 19  0.003818

# %%
result_BN = plot_hp_tuning("BN", n_synthetic_datasets=25)
# Out:
#   0%|          | 0/75 [00:00<?, ?it/s]

# %%
result_BN
# Out:
#    Batch normalization generator Concatenate with previous layer  \
# 0                          False                           False
# 1                           True                           False
# 2                           True                            True
#
#    Value Accuracy  Value AUC  Value F1  Value F1_0  Value F1_1  SD Accuracy  \
# 0        0.838745   0.892077  0.773739    0.895011    0.652468     0.001572
# 1        0.842271   0.896247  0.778148    0.897417    0.658879     0.002051
# 2        0.842643   0.895979  0.778428    0.897706    0.659149     0.002358
#
#      SD AUC     SD F1   SD F1_0   SD F1_1
# 0  0.001353  0.002721  0.001119  0.004990
# 1  0.001825  0.002804  0.001434  0.004551
# 2  0.001651  0.003612  0.001563  0.006000

# %%
result_BN_advanced = plot_hp_tuning("BN_advanced")
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]

# %%
result_BN_advanced

# %%
result_LN_advanced = plot_hp_tuning("LN_advanced")
# Out:
#   0%|          | 0/125 [00:00<?, ?it/s]

# %%
result_dropout_critic = plot_hp_tuning("critic_dropout")
# Out:
#   0%|          | 0/70 [00:00<?, ?it/s]

# %%
result_adam_betas = plot_hp_tuning("adam_betas")
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
import pandas as pd
df = pd.read_csv(os.path.join(const.dir.data_comparison(), "creditcard_edited.csv"))

# %%
df.select_dtypes(exclude=[np.number]).columns.values
# Out:
# array(['Class'], dtype=object)

# %%
df.select_dtypes(include=[np.number]).columns.values
# Out:
# array(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9',
#        'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18',
#        'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27',
#        'V28', 'Amount'], dtype=object)

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#          Class
# 0       Class0
# 1       Class0
# 2       Class0
# 3       Class0
# 4       Class0
# ...        ...
# 284802  Class0
# 284803  Class0
# 284804  Class0
# 284805  Class0
# 284806  Class0
#
# [284807 rows x 31 columns]

# %%
import pandas as pd
df = pd.read_csv(os.path.join(const.dir.data_comparison(), "covtype_edited.csv"))

# %%
train_indices = np.load(os.path.join(const.dir.data_comparison(), "indices", "covtype_edited", "bool_indices_14.npy"))

# %%
df
# Out:
#          Wilderness_Area    Soil_Type  Elevation  Aspect  Slope  \
# 0       Wilderness_Area1  Soil_Type29       2596      51      3
# 1       Wilderness_Area1  Soil_Type29       2590      56      2
# 2       Wilderness_Area1  Soil_Type12       2804     139      9
# 3       Wilderness_Area1  Soil_Type30       2785     155     18
# 4       Wilderness_Area1  Soil_Type29       2595      45      2
# ...                  ...          ...        ...     ...    ...
# 581007  Wilderness_Area3   Soil_Type2       2396     153     20
# 581008  Wilderness_Area3   Soil_Type2       2391     152     19
# 581009  Wilderness_Area3   Soil_Type2       2386     159     17
# 581010  Wilderness_Area3   Soil_Type2       2384     170     15
# 581011  Wilderness_Area3   Soil_Type2       2383     165     13
#
#         Horizontal_Distance_To_Hydrology  Vertical_Distance_To_Hydrology  \
# 0                                    258                               0
# 1                                    212                              -6
# 2                                    268                              65
# 3                                    242                             118
# 4                                    153                              -1
# ...                                  ...                             ...
# 581007                                85                              17
# 581008                                67                              12
# 581009                                60                               7
# 581010                                60                               5
# 581011                                60                               4
#
#         Horizontal_Distance_To_Roadways  Hillshade_9am  Hillshade_Noon  \
# 0                                   510            221             232
# 1                                   390            220             235
# 2                                  3180            234             238
# 3                                  3090            238             238
# 4                                   391            220             234
# ...                                 ...            ...             ...
# 581007                              108            240             237
# 581008                               95            240             237
# 581009                               90            236             241
# 581010                               90            230             245
# 581011                               67            231             244
#
#         Hillshade_3pm  Horizontal_Distance_To_Fire_Points  Cover_Type
# 0                 148                                6279  CoverType5
# 1                 151                                6225  CoverType5
# 2                 135                                6121  CoverType2
# 3                 122                                6211  CoverType2
# 4                 150                                6172  CoverType5
# ...               ...                                 ...         ...
# 581007            118                                 837  CoverType3
# 581008            119                                 845  CoverType3
# 581009            130                                 854  CoverType3
# 581010            143                                 864  CoverType3
# 581011            141                                 875  CoverType3
#
# [581012 rows x 13 columns]

# %%
np.sort(df.loc[train_indices, "Soil_Type"].unique())
# Out:
# array(['Soil_Type1', 'Soil_Type10', 'Soil_Type11', 'Soil_Type12',
#        'Soil_Type13', 'Soil_Type14', 'Soil_Type15', 'Soil_Type16',
#        'Soil_Type17', 'Soil_Type18', 'Soil_Type19', 'Soil_Type2',
#        'Soil_Type20', 'Soil_Type21', 'Soil_Type22', 'Soil_Type23',
#        'Soil_Type24', 'Soil_Type25', 'Soil_Type26', 'Soil_Type27',
#        'Soil_Type28', 'Soil_Type29', 'Soil_Type3', 'Soil_Type30',
#        'Soil_Type31', 'Soil_Type32', 'Soil_Type33', 'Soil_Type34',
#        'Soil_Type35', 'Soil_Type36', 'Soil_Type37', 'Soil_Type38',
#        'Soil_Type39', 'Soil_Type4', 'Soil_Type40', 'Soil_Type5',
#        'Soil_Type6', 'Soil_Type7', 'Soil_Type8', 'Soil_Type9'],
#       dtype=object)

# %%
np.sort(df.loc[~train_indices, "Soil_Type"].unique())
# Out:
# array(['Soil_Type1', 'Soil_Type10', 'Soil_Type11', 'Soil_Type12',
#        'Soil_Type13', 'Soil_Type14', 'Soil_Type16', 'Soil_Type17',
#        'Soil_Type18', 'Soil_Type19', 'Soil_Type2', 'Soil_Type20',
#        'Soil_Type21', 'Soil_Type22', 'Soil_Type23', 'Soil_Type24',
#        'Soil_Type25', 'Soil_Type26', 'Soil_Type27', 'Soil_Type28',
#        'Soil_Type29', 'Soil_Type3', 'Soil_Type30', 'Soil_Type31',
#        'Soil_Type32', 'Soil_Type33', 'Soil_Type34', 'Soil_Type35',
#        'Soil_Type36', 'Soil_Type37', 'Soil_Type38', 'Soil_Type39',
#        'Soil_Type4', 'Soil_Type40', 'Soil_Type5', 'Soil_Type6',
#        'Soil_Type7', 'Soil_Type8', 'Soil_Type9'], dtype=object)
