# %%
import pathlib
import os
if not "changed_working_directory" in locals():
    changed_working_directory = True
    os.chdir(pathlib.Path().resolve().parent)
    
# %load_ext autoreload
# %autoreload 2

import pandas as pd

from src import constants as const
dataset_train_path = os.path.join(const.dir.data(), "df_adult_edited_train.csv")
dataset_test_path = os.path.join(const.dir.data(), "df_adult_edited_test.csv")

data_train = pd.read_csv(dataset_train_path)
data_test = pd.read_csv(dataset_test_path)
discrete_columns = data_train.columns[data_train.dtypes == "object"]

imports_path = "src//imports.ipynb"

# %run "$imports_path"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy
creditcard_edited = pd.read_csv(os.path.join(const.dir.data(), "comparison", "creditcard.csv"))
creditcard_edited.loc[:, "Class"] = "Class" + creditcard.loc[:, "Class"].astype("string")
creditcard_edited
creditcard_edited.to_csv(os.path.join(const.dir.data(), "comparison", "creditcard_edited.csv"), index=False)

# %%
creditcard_edited
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#          Class
# 0       Class0
# 1       Class0
# 2       Class0
# 3       Class0
# 4       Class0
# ...        ...
# 284802  Class0
# 284803  Class0
# 284804  Class0
# 284805  Class0
# 284806  Class0
#
# [284807 rows x 31 columns]

# %%
pd.read_csv(os.path.join(const.dir.data(), "comparison", "creditcard_edited.csv")).dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class      object
# dtype: object

# %%
import pandas as pd
import numpy
covtype = pd.read_csv(os.path.join(const.dir.data(), "comparison", "covtype.csv"))
covtype_edited = covtype.iloc[:, ~ covtype.columns.str.contains("^(Soil_Type|Wilderness_Area)", regex=True)]
covtype_edited.insert(0, "Soil_Type", covtype.loc[:, covtype.columns.str.startswith("Soil_Type")].idxmax(axis=1))
covtype_edited.insert(0, "Wilderness_Area", covtype.loc[:, covtype.columns.str.startswith("Wilderness_Area")].idxmax(axis=1))
covtype_edited.loc[:, "Cover_Type"] = "CoverType" + covtype.loc[:, "Cover_Type"].astype("string")
covtype_edited.to_csv(os.path.join(const.dir.data(), "comparison", "covtype_edited.csv"), index=False)
covtype_edited
# Out:
#          Wilderness_Area    Soil_Type  Elevation  Aspect  Slope  \
# 0       Wilderness_Area1  Soil_Type29       2596      51      3
# 1       Wilderness_Area1  Soil_Type29       2590      56      2
# 2       Wilderness_Area1  Soil_Type12       2804     139      9
# 3       Wilderness_Area1  Soil_Type30       2785     155     18
# 4       Wilderness_Area1  Soil_Type29       2595      45      2
# ...                  ...          ...        ...     ...    ...
# 581007  Wilderness_Area3   Soil_Type2       2396     153     20
# 581008  Wilderness_Area3   Soil_Type2       2391     152     19
# 581009  Wilderness_Area3   Soil_Type2       2386     159     17
# 581010  Wilderness_Area3   Soil_Type2       2384     170     15
# 581011  Wilderness_Area3   Soil_Type2       2383     165     13
#
#         Horizontal_Distance_To_Hydrology  Vertical_Distance_To_Hydrology  \
# 0                                    258                               0
# 1                                    212                              -6
# 2                                    268                              65
# 3                                    242                             118
# 4                                    153                              -1
# ...                                  ...                             ...
# 581007                                85                              17
# 581008                                67                              12
# 581009                                60                               7
# 581010                                60                               5
# 581011                                60                               4
#
#         Horizontal_Distance_To_Roadways  Hillshade_9am  Hillshade_Noon  \
# 0                                   510            221             232
# 1                                   390            220             235
# 2                                  3180            234             238
# 3                                  3090            238             238
# 4                                   391            220             234
# ...                                 ...            ...             ...
# 581007                              108            240             237
# 581008                               95            240             237
# 581009                               90            236             241
# 581010                               90            230             245
# 581011                               67            231             244
#
#         Hillshade_3pm  Horizontal_Distance_To_Fire_Points  Cover_Type
# 0                 148                                6279  CoverType5
# 1                 151                                6225  CoverType5
# 2                 135                                6121  CoverType2
# 3                 122                                6211  CoverType2
# 4                 150                                6172  CoverType5
# ...               ...                                 ...         ...
# 581007            118                                 837  CoverType3
# 581008            119                                 845  CoverType3
# 581009            130                                 854  CoverType3
# 581010            143                                 864  CoverType3
# 581011            141                                 875  CoverType3
#
# [581012 rows x 13 columns]

# %%
news.loc[:, news.columns.str.contains("^(LDA)")]
# Out:
#          LDA_00    LDA_01    LDA_02    LDA_03    LDA_04
# 0      0.500331  0.378279  0.040005  0.041263  0.040123
# 1      0.799756  0.050047  0.050096  0.050101  0.050001
# 2      0.217792  0.033334  0.033351  0.033334  0.682188
# 3      0.028573  0.419300  0.494651  0.028905  0.028572
# 4      0.028633  0.028794  0.028575  0.028572  0.885427
# ...         ...       ...       ...       ...       ...
# 39639  0.025038  0.025001  0.151701  0.025000  0.773260
# 39640  0.029349  0.028575  0.231866  0.681635  0.028575
# 39641  0.159004  0.025025  0.025207  0.643794  0.146970
# 39642  0.040004  0.040003  0.839987  0.040002  0.040004
# 39643  0.050001  0.799339  0.050000  0.050659  0.050001
#
# [39644 rows x 5 columns]

# %%
import pandas as pd
import numpy
news = pd.read_csv(os.path.join(const.dir.data(), "comparison", "OnlineNewsPopularity.csv"))
news.columns = [column.strip() for column in news.columns]
news_edited = news.loc[:, ~ news.columns.str.contains("^(weekday_is|data_channel)")]
news_edited = news_edited.drop("url", axis=1)
news_edited.insert(
    0, "weekday",
    news.loc[:, news.columns.str.contains("^weekday_is")].idxmax(axis=1).str.replace("weekday_is_", "").str.title()
)
news_edited.insert(0, "data_channel",
                   news.loc[:, news.columns.str.contains("^data_channel")].idxmax(axis=1).str.replace("data_channel_is_", ""))
#news_edited.loc[:, "Class"] = "Class" + news.loc[:, "Class"].astype("string")
news_edited.loc[:, "is_weekend"] = np.where(news_edited.loc[:, "is_weekend"] > 0.5, "yes", "no")
news_edited.to_csv(os.path.join(const.dir.data(), "comparison", "news_edited.csv"), index=False)
news_edited
# Out:
#         data_channel    weekday  timedelta  n_tokens_title  n_tokens_content  \
# 0      entertainment     Monday      731.0            12.0             219.0
# 1                bus     Monday      731.0             9.0             255.0
# 2                bus     Monday      731.0             9.0             211.0
# 3      entertainment     Monday      731.0             9.0             531.0
# 4               tech     Monday      731.0            13.0            1072.0
# ...              ...        ...        ...             ...               ...
# 39639           tech  Wednesday        8.0            11.0             346.0
# 39640         socmed  Wednesday        8.0            12.0             328.0
# 39641      lifestyle  Wednesday        8.0            10.0             442.0
# 39642          world  Wednesday        8.0             6.0             682.0
# 39643  entertainment  Wednesday        8.0            10.0             157.0
#
#        n_unique_tokens  n_non_stop_words  n_non_stop_unique_tokens  num_hrefs  \
# 0             0.663594               1.0                  0.815385        4.0
# 1             0.604743               1.0                  0.791946        3.0
# 2             0.575130               1.0                  0.663866        3.0
# 3             0.503788               1.0                  0.665635        9.0
# 4             0.415646               1.0                  0.540890       19.0
# ...                ...               ...                       ...        ...
# 39639         0.529052               1.0                  0.684783        9.0
# 39640         0.696296               1.0                  0.885057        9.0
# 39641         0.516355               1.0                  0.644128       24.0
# 39642         0.539493               1.0                  0.692661       10.0
# 39643         0.701987               1.0                  0.846154        1.0
#
#        num_self_hrefs  ...  min_positive_polarity  max_positive_polarity  \
# 0                 2.0  ...               0.100000                   0.70
# 1                 1.0  ...               0.033333                   0.70
# 2                 1.0  ...               0.100000                   1.00
# 3                 0.0  ...               0.136364                   0.80
# 4                19.0  ...               0.033333                   1.00
# ...               ...  ...                    ...                    ...
# 39639             7.0  ...               0.100000                   0.75
# 39640             7.0  ...               0.136364                   0.70
# 39641             1.0  ...               0.136364                   0.50
# 39642             1.0  ...               0.062500                   0.50
# 39643             1.0  ...               0.100000                   0.50
#
#        avg_negative_polarity  min_negative_polarity  max_negative_polarity  \
# 0                  -0.350000                 -0.600              -0.200000
# 1                  -0.118750                 -0.125              -0.100000
# 2                  -0.466667                 -0.800              -0.133333
# 3                  -0.369697                 -0.600              -0.166667
# 4                  -0.220192                 -0.500              -0.050000
# ...                      ...                    ...                    ...
# 39639              -0.260000                 -0.500              -0.125000
# 39640              -0.211111                 -0.400              -0.100000
# 39641              -0.356439                 -0.800              -0.166667
# 39642              -0.205246                 -0.500              -0.012500
# 39643              -0.200000                 -0.200              -0.200000
#
#        title_subjectivity  title_sentiment_polarity  abs_title_subjectivity  \
# 0                0.500000                 -0.187500                0.000000
# 1                0.000000                  0.000000                0.500000
# 2                0.000000                  0.000000                0.500000
# 3                0.000000                  0.000000                0.500000
# 4                0.454545                  0.136364                0.045455
# ...                   ...                       ...                     ...
# 39639            0.100000                  0.000000                0.400000
# 39640            0.300000                  1.000000                0.200000
# 39641            0.454545                  0.136364                0.045455
# 39642            0.000000                  0.000000                0.500000
# 39643            0.333333                  0.250000                0.166667
#
#        abs_title_sentiment_polarity  shares
# 0                          0.187500     593
# 1                          0.000000     711
# 2                          0.000000    1500
# 3                          0.000000    1200
# 4                          0.136364     505
# ...                             ...     ...
# 39639                      0.000000    1800
# 39640                      1.000000    1900
# 39641                      0.136364    1900
# 39642                      0.000000    1100
# 39643                      0.250000    1300
#
# [39644 rows x 49 columns]

# %%
import sklearn.model_selection
import helpers
creditcard_train, creditcard_test = sklearn.model_selection.train_test_split(creditcard_edited, train_size=0.7)
metrics, cats = helpers.eval.fit_and_evaluate_xgboost(creditcard_train, creditcard_test, response_col="Class",
                                                    retcats=True, metrics=["accuracy", "auc", "f1", "f1_1", "f1_0"])
metrics
# Out:
# False
# {'accuracy': 0.9996137776061234,
#  'auc': 0.9783975454170216,
#  'f1': 0.9415993973071903,
#  'f1_0': 0.9998065684659707,
#  'f1_1': 0.88339222614841}

# %%
import sklearn.model_selection
import helpers
covtype_train, covtype_test = sklearn.model_selection.train_test_split(covtype_edited, train_size=0.7)
metrics, cats = helpers.eval.fit_and_evaluate_xgboost(covtype_train, covtype_test, response_col="Cover_Type",
                                                    retcats=True, metrics=["accuracy", "f1"])
metrics
# Out:
# False
# {'accuracy': 0.8721142371947861, 'f1': 0.869656239628934}

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot
import numpy
# load data
# split data into X and y
X = news.drop(["url", "shares"], axis=1)
y = news["shares"]
# encode string class values as integers
# grid search
model = XGBRegressor()
n_estimators = [50, 100, 150, 200]
max_depth = [2, 4, 6, 8]
print(max_depth)
param_grid = dict(max_depth=max_depth, n_estimators=n_estimators)
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
grid_search = GridSearchCV(model, param_grid, scoring="neg_mean_squared_error", n_jobs=-1, cv=kfold, verbose=1)
grid_result = grid_search.fit(X, y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))
# plot results
scores = numpy.array(means).reshape(len(max_depth), len(n_estimators))
for i, value in enumerate(max_depth):
    pyplot.plot(n_estimators, scores[i], label='depth: ' + str(value))
pyplot.legend()
pyplot.xlabel('n_estimators')
pyplot.ylabel('MSE')
pyplot.savefig(os.path.join(const.dir.data(), 'news_sklearn_n_estimators_vs_max_depth.png'))
# Out:
# [2, 4, 6, 8]
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 28 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed: 11.8min finished
# Best: -136162619.523113 using {'max_depth': 2, 'n_estimators': 50}
# -136162619.523113 (62083166.437311) with: {'max_depth': 2, 'n_estimators': 50}
# -138960203.661963 (62628594.524134) with: {'max_depth': 2, 'n_estimators': 100}
# -140127261.587370 (61943710.122195) with: {'max_depth': 2, 'n_estimators': 150}
# -142512887.529932 (63133623.280857) with: {'max_depth': 2, 'n_estimators': 200}
# -145151582.059238 (60204133.296365) with: {'max_depth': 4, 'n_estimators': 50}
# -149145723.848884 (58464195.639103) with: {'max_depth': 4, 'n_estimators': 100}
# -151000689.511865 (58177838.463714) with: {'max_depth': 4, 'n_estimators': 150}
# -152236008.612865 (58275391.488654) with: {'max_depth': 4, 'n_estimators': 200}
# -148521381.654570 (59839655.011140) with: {'max_depth': 6, 'n_estimators': 50}
# -151583135.523923 (59835542.343227) with: {'max_depth': 6, 'n_estimators': 100}
# -152729746.494512 (59722550.188884) with: {'max_depth': 6, 'n_estimators': 150}
# -153464333.992997 (59768861.214293) with: {'max_depth': 6, 'n_estimators': 200}
# -151614029.915038 (59905054.662242) with: {'max_depth': 8, 'n_estimators': 50}
# -152949793.617006 (59549411.592409) with: {'max_depth': 8, 'n_estimators': 100}
# -153710686.679968 (59621448.877982) with: {'max_depth': 8, 'n_estimators': 150}
# -154037290.568023 (59574614.659278) with: {'max_depth': 8, 'n_estimators': 200}

# %%
from matplotlib import pyplot as plt
matplotlib.use('NbAgg')
plt.figure()
plt.hist(news_edited["shares"], bins=3000)
plt.xlim(0, 20000)
plt.vlines(1500, 0, 7000, colors="black")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
news_edited.assign(shares=lambda x: np.where(x.shares > 1500, np.where(x.shares > 10000, ">10000", "2500-1000"), "0-2500")
                  )["shares"].value_counts()
# Out:
# 0-2500       21405
# 2500-1000    16054
# >10000        2185
# Name: shares, dtype: int64

# %%
28778 / (28778 + 8681 + 2185)
# Out:
# 0.7259106043789728

# %%
import sklearn.model_selection
import helpers
news_train, news_test = sklearn.model_selection.train_test_split(
    news_edited.assign(shares=lambda x: np.where(x.shares > 3395, "Popular", "Unpopular")), test_size=0.3)
metrics, cats = helpers.eval.fit_and_evaluate_xgboost(news_train, news_test, response_col="shares",
                                                    retcats=True, metrics=["accuracy", "auc", "f1", "f1_0"],
                                                     model_type="xgboost")
metrics
# Out:
# {'accuracy': 0.7849335799562804,
#  'auc': 0.6889996454783403,
#  'f1': 0.5524970769864093,
#  'f1_0': 0.2299819385912101}

# %%
from tabGAN import TabGAN
tg_qtr = TabGAN(news_edited, batch_size=500, ctgan=True, n_critic=10, adam_beta1 = 0.5,
                 quantile_transformation_int=True, quantile_rand_transformation=True, qtr_spread=1,
                 activation_function="mish", jit_compile=True, qt_n_subsample=int(1e5))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /work/arneir/ipykernel_4136587/3359711390.py in <module>
#       1 from tabGAN import TabGAN
# ----> 2 tg_qtr = TabGAN(news_edited, batch_size=500, ctgan=True, n_critic=10, adam_beta1 = 0.5,
#       3                  quantile_transformation_int=True, quantile_rand_transformation=True, qtr_spread=1,
#       4                  activation_function="mish", jit_compile=True, qt_n_subsample=int(1e5))
#
# ~/Master-thesis-cf/tabGAN/tabGAN.py in __init__(self, data, batch_size, gan_method, wgan_lambda, pac, n_hidden_layers, n_hidden_generator_layers, n_hidden_critic_layers, dim_hidden, dim_hidden_generator, dim_hidden_critic, dim_latent, n_critic, quantile_transformation_int, max_quantile_share, print_quantile_shares, qt_distribution, latent_distribution, oh_encoding_activation_function, gumbel_temperature, n_quantiles_int, qt_n_subsample, quantile_rand_transformation, qtr_spread, qtr_lbound_apply, qtr_uniform_on_normal_scale, qtr_distribution, qtr_beta_distribution_parameter, reapply_qtr_continuously, ctgan, ctgan_log_frequency, ctgan_binomial_loss, ctgan_binomial_distance_floor, train_step_critic_same_queries_for_critic_and_gen, train_step_critic_wgan_penalty_query_diversity, train_step_critic_query_wgan_penalty, critic_use_query_input, activation_function, leaky_relu_alpha, gelu_approximate, elu_alpha, activation_function_critic, activation_function_generator, add_dropout_critic, add_dropout_generator, dropout_rate, dropout_rate_critic, dropout_rate_generator, add_connection_discrete_to_num, add_connection_num_to_discrete, add_connection_activation_function, dim_hidden_layer_discrete_to_num, dim_hidden_layer_num_to_discrete, add_connection_query_to_discrete, optimizer, opt_lr, adam_beta1, adam_beta2, sgd_momentum, adam_amsgrad, sgd_nesterov, rmsprop_rho, rmsprop_momentum, rmsprop_centered, ckpt_dir, ckpt_every, ckpt_max_to_keep, ckpt_name, noise_discrete_unif_max, use_query, np_data_fix, tf_data_use, tf_data_shuffle, tf_data_prefetch, tf_data_cache, tf_make_graph, tf_make_critic_step_graph, tf_make_gen_step_graph, tf_make_train_step_graph, tf_make_numpy_data_step_graph, tf_make_em_distance_graph, tf_make_generate_latent_graph, jit_compile, jit_compile_critic_step, jit_compile_gen_step, jit_compile_numpy_data_step, jit_compile_generate_latent, jit_compile_em_distance, default_epochs_to_train)
#      74         if "mish" in [activation_function_critic, activation_function_generator] or \
#      75                 (oh_encoding_activation_function is not None and oh_encoding_activation_function.lower() == "mish"):
# ---> 76             from tensorflow_addons.activations import mish
#      77         else:
#      78             mish = None
#
# ModuleNotFoundError: No module named 'tensorflow_addons'

# %%
metrics, cats = helpers.eval.fit_and_evaluate_xgboost(news_train, news_test, response_col="shares",
                                                    retcats=True, metrics=["sqmse", "rmse", "mae"],
                                                     model_type="elastic net cv",
                                                      model_params={"l1_ratio": 1})
print(metrics)
print(np.mean(news_test["shares"]))
print("Mse mean model:", (np.mean((news_test["shares"] - np.mean(news_train["shares"]))**2)))
print("squared root mse mean model:", np.sqrt(np.mean((news_test["shares"] - np.mean(news_train["shares"]))**2)))
print("mae mean model:", np.mean(np.abs((news_test["shares"] - np.mean(news_train["shares"])))))
# Out:
# {'mse': 169665257.01222605, 'rmse': 13025.561677418216, 'mae': 3072.3939977791506}
# 3414.6415839919287
# Mse mean model: 171847868.64930624
# squared root mse mean model: 13109.075812173269
# mae mean model: 3212.5885537864174

# %%
np.sqrt(136162619)
# Out:
# 11668.87393881689

# %%
np.sqrt(125855907)
# Out:
# 11218.551911900217

# %%
sklearn.metrics.precision_recall_curve([0,1,0,1], [0.2, 0.1, 0.5, 0.2])

# %%
from tabGAN import TabGAN
tg_qtr = TabGAN(creditcard, batch_size=2000, ctgan=True, n_critic=10, adam_beta1 = 0.5,
                 quantile_transformation_int=True, quantile_rand_transformation=True, qtr_spread=1,
                 activation_function="mish", jit_compile=True, qt_n_subsample=int(1e5))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /work/arneir/ipykernel_4136587/1334240937.py in <module>
#       1 from tabGAN import TabGAN
# ----> 2 tg_qtr = TabGAN(creditcard, batch_size=2000, ctgan=True, n_critic=10, adam_beta1 = 0.5,
#       3                  quantile_transformation_int=True, quantile_rand_transformation=True, qtr_spread=1,
#       4                  activation_function="mish", jit_compile=True, qt_n_subsample=int(1e5))
#
# ~/Master-thesis-cf/tabGAN/tabGAN.py in __init__(self, data, batch_size, gan_method, wgan_lambda, pac, n_hidden_layers, n_hidden_generator_layers, n_hidden_critic_layers, dim_hidden, dim_hidden_generator, dim_hidden_critic, dim_latent, n_critic, quantile_transformation_int, max_quantile_share, print_quantile_shares, qt_distribution, latent_distribution, oh_encoding_activation_function, gumbel_temperature, n_quantiles_int, qt_n_subsample, quantile_rand_transformation, qtr_spread, qtr_lbound_apply, qtr_uniform_on_normal_scale, qtr_distribution, qtr_beta_distribution_parameter, reapply_qtr_continuously, ctgan, ctgan_log_frequency, ctgan_binomial_loss, ctgan_binomial_distance_floor, train_step_critic_same_queries_for_critic_and_gen, train_step_critic_wgan_penalty_query_diversity, train_step_critic_query_wgan_penalty, critic_use_query_input, activation_function, leaky_relu_alpha, gelu_approximate, elu_alpha, activation_function_critic, activation_function_generator, add_dropout_critic, add_dropout_generator, dropout_rate, dropout_rate_critic, dropout_rate_generator, add_connection_discrete_to_num, add_connection_num_to_discrete, add_connection_activation_function, dim_hidden_layer_discrete_to_num, dim_hidden_layer_num_to_discrete, add_connection_query_to_discrete, optimizer, opt_lr, adam_beta1, adam_beta2, sgd_momentum, adam_amsgrad, sgd_nesterov, rmsprop_rho, rmsprop_momentum, rmsprop_centered, ckpt_dir, ckpt_every, ckpt_max_to_keep, ckpt_name, noise_discrete_unif_max, use_query, np_data_fix, tf_data_use, tf_data_shuffle, tf_data_prefetch, tf_data_cache, tf_make_graph, tf_make_critic_step_graph, tf_make_gen_step_graph, tf_make_train_step_graph, tf_make_numpy_data_step_graph, tf_make_em_distance_graph, tf_make_generate_latent_graph, jit_compile, jit_compile_critic_step, jit_compile_gen_step, jit_compile_numpy_data_step, jit_compile_generate_latent, jit_compile_em_distance, default_epochs_to_train)
#      74         if "mish" in [activation_function_critic, activation_function_generator] or \
#      75                 (oh_encoding_activation_function is not None and oh_encoding_activation_function.lower() == "mish"):
# ---> 76             from tensorflow_addons.activations import mish
#      77         else:
#      78             mish = None
#
# ModuleNotFoundError: No module named 'tensorflow_addons'

# %%
tg_qtr.train(100, progress_bar=True)

# %%
helpers.eval.fit_and_evaluate_xgboost(tg_qtr.sample(), credit_test, response_col="default.payment.next.month",
                                                    categories=cats)
